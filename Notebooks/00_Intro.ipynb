# %% [markdown]
# # Welcome to Chem269C - Intro to data analysis
#
# ## 1. Goals of this class.
# - Learn to control your robot
# - Learn some statistics (more below).
# - Introduction to spatial gene expression datasets
# - Learn to present data in a meaningful way (dataviz)
#
# ## 2. Setting Up the Environment
# - Overview of python / libraries (conda and pip) / cursor / jupyter
#
# ## 3. Understanding the Dataset
# - Introduction to the spatial gene expression dataset
# - How to load the dataset
# - Basic operations to explore the dataset
#
# ## 4. Introduction to Data Visualization
# - Importance of data visualization in statistical analysis
# - Basic data visualization techniques
#
# ## 5. Introduction to Clustering and Dimensionality Reduction
# - What is clustering?
# - What is dimensionality reduction?
# - Why are they important in statistical analysis?
#
# ## 6. Introduction to Probability Statements
# - Basic concepts of probability
# - Introduction to permutations and bootstrap
# - Importance of these concepts in statistical analysis
#
# ## 7. Assignments
# - find clusters and show their differences in a low dim space of your chosing.
# - determine if a gene is "spatially differentially expressed"
# - determine the statistical confidence of cell-type interactions
#
# ## 8. Summary and Next Steps
# - Recap of the topics covered
# - Introduction to the topics that will be covered in the next notebooks
#
# ## 9. References and Further Reading
# - Links to useful resources for further learning
#
# ## 10. Exercises
# - Set of exercises for students to practice the concepts learned in this notebook

# %% [markdown]
# ### What are robots good for? a demonstration

# %%
import numpy as np
import matplotlib.pyplot as plt

sig = 20
slp = 0.3
x = np.random.uniform(0, 100, 1000)
y = x + slp * np.random.normal(0, sig, 1000)

plt.plot(x,y,'.')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# <span style='color:orange'>repeat the code about for six values of sigma (10,20,30,60,100,150) and create a 2 by 3 subplots showing this data with the value of sig in the title</span>

# %% [markdown]
# In the chat (ctrl-L) ask the following:
#
# <span style='color:orange'>What statistcal analysis would you recommend to estimate the spread of the values of Y around X taking into account the trendline?</span>
#
# Copy the code and see that it makes sense.

# %% [markdown]
# If you are unsure, ask the robot for clarification in the chat. For example:
#
# <span style='color:orange'>explain what the stats.linregress is doing, I don't know what regression is.</span>

# %% [markdown]
# Now ask your robot to:
#
# <span style='color:orange'> repeat the regression analysis with decreasing sample sizes (from 2 to 1000) and in each case estimate sigma, create a plot of the error in sigma as a function of sample size</span>

# %% [markdown]
# # **You don't need to learn how to code, you need to learn how to ask questions!**
